# %%
import pandas as pd

train_path = '/home/sk/Downloads/insurance_claim/train.csv'
test_path = '/home/sk/Downloads/insurance_claim/test.csv'

train_data = pd.read_csv(train_path) 
test_data = pd.read_csv(test_path)

# %%
train_data.columns
# Out:
# Index(['id', 'cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7',
#        'cat8', 'cat9', 'cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5',
#        'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12',
#        'cont13', 'target'],
#       dtype='object')

# %%
features = train_data.columns.tolist()[1:-1]

# %%
features
# Out:
# ['cat0',
#  'cat1',
#  'cat2',
#  'cat3',
#  'cat4',
#  'cat5',
#  'cat6',
#  'cat7',
#  'cat8',
#  'cat9',
#  'cont0',
#  'cont1',
#  'cont2',
#  'cont3',
#  'cont4',
#  'cont5',
#  'cont6',
#  'cont7',
#  'cont8',
#  'cont9',
#  'cont10',
#  'cont11',
#  'cont12',
#  'cont13']

# %%
train_data[features].head()
# Out:
#   cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont4     cont5  \
# 0    B    B    B    C    B    B    A    E    C    N  ...  0.610706  0.400361
# 1    B    B    A    A    B    D    A    F    A    O  ...  0.276853  0.533087
# 2    A    A    A    C    B    D    A    D    A    F  ...  0.285074  0.650609
# 3    B    B    A    C    B    D    A    E    C    K  ...  0.284667  0.668980
# 4    A    A    A    C    B    D    A    E    A    N  ...  0.287595  0.686964
#
#       cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# 0  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401
# 1  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975
# 2  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474
# 3  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150
# 4  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849
#
#      cont13
# 0  0.869850
# 1  0.465083
# 2  0.763846
# 3  0.280682
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

def convert(data):
    number = LabelEncoder()
    for i in features:
        if not i.isdigit():
            le.fit(data[i].astype(str))
            data[i] = le.transform(data[i].astype(str))
    data = data.fillna(-999)
    return data

train_data = convert(train_data)
test_data = convert(test_data)

# %%
train_data.head()
# Out:
#    id  cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  ...   cont5  \
# 0   1     1     1     1     2     1     1     0     4     2  ...  103440
# 1   2     1     1     0     0     1     3     0     5     0  ...  175395
# 2   3     0     0     0     2     1     3     0     3     0  ...  217899
# 3   4     1     1     0     2     1     3     0     4     2  ...  224580
# 4   6     0     0     0     2     1     3     0     4     0  ...  231012
#
#     cont6   cont7   cont8   cont9  cont10  cont11  cont12  cont13    target
# 0   13112   47407  124269   44203   62107  114766   93133  293019  8.113634
# 1  218060  155840  216428   93128  286775  290317   49548  144317  8.481233
# 2  104083  288898  191569  282515  252433  209854  169893  231581  8.364351
# 3   29072  229975  239973  210675  112833  249815  169712   55498  8.049253
# 4  141959  208075  240648  297313  296888  275696  192992   30052  7.972260
#
# [5 rows x 26 columns]

# %%
y = train_data.target
X = train_data[features]

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y, train_size=0.8, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

forest_model = RandomForestRegressor()

forest_model.fit(train_X, train_y)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_absolute_error

preds_val = forest_model.predict(val_X)
mae = mean_absolute_error(val_y, preds_val)

# %%
mae
# Out:
# 0.5823324709732621

# %%
forest_model.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
text_X = test_data[features]

# %%
final_predict_ap02 = forest_model.predict(text_X)

# %%
output_ap02 = pd.DataFrame({'id': test_data.id, 'target': final_predict})
output_ap02.to_csv('/home/sk/Downloads/insurance_claim/my_submission_ap02.csv', index=False)

# %%
test_data
# Out:
#             id  cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  ...  \
# 0            0     1     1     1     2     1     1     0     4     4  ...
# 1            5     0     1     0     2     1     2     0     4     2  ...
# 2           15     1     0     0     0     1     1     0     4     3  ...
# 3           16     1     1     0     2     1     3     0     4     0  ...
# 4           17     1     1     0     2     1     2     0     4     2  ...
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 199995  499987     1     0     0     2     1     3     0     4     4  ...
# 199996  499990     1     0     0     2     1     1     0     4     2  ...
# 199997  499991     0     1     1     2     1     1     0     4     2  ...
# 199998  499994     0     0     0     2     1     3     0     3     0  ...
# 199999  499995     0     0     0     2     1     3     0     4     0  ...
#
#          cont4   cont5   cont6   cont7   cont8   cont9  cont10  cont11  \
# ...

# %%
output
# Out:
#             id    target
# 0            0  7.937411
# 1            5  8.160680
# 2           15  8.177290
# 3           16  8.101081
# 4           17  8.276906
# ...        ...       ...
# 199995  499987  8.444417
# 199996  499990  8.283441
# 199997  499991  8.200046
# 199998  499994  8.142996
# 199999  499995  8.367418
#
# [200000 rows x 2 columns]

# %%
from numba import jit

# Function for calculating MAE that is denepdant on the bumber of forests
from sklearn.metrics import mean_absolute_error

def get_mae(estimators, train_X, val_X, train_y, val_y):
    model = RandomForestRegressor(max_depth=estimators)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
# Try to calculate the best number of forests
d_estimators = dict()

for estimators in [1, 10, 20]:
    my_mae = get_mae(estimators, train_X, val_X, train_y, val_y)
    #print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(estimators, my_mae))
    d_estimators[my_mae] = estimators

print(min(d_estimators), 'estimator n is', d_estimators[min(d_estimators)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-20b17b4b9b07> in <module>
#       3
#       4 for estimators in [1, 10, 20]:
# ----> 5     my_mae = get_mae(estimators, train_X, val_X, train_y, val_y)
#       6     #print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(estimators, my_mae))
#       7     d_estimators[my_mae] = estimators
#
# <ipython-input-60-1bf1b6b45e0a> in get_mae(estimators, train_X, val_X, train_y, val_y)
#       6 def get_mae(estimators, train_X, val_X, train_y, val_y):
#       7     model = RandomForestRegressor(max_depth=estimators)
# ----> 8     model.fit(train_X, train_y)
#       9     preds_val = model.predict(val_X)
#      10     mae = mean_absolute_error(val_y, preds_val)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
# ...
