# %%
import pandas as pd
f500 = pd.read_csv('fortune_500.csv',index_col=1)
f500.index.name = None

# %%
f500.shape
# Out:
# (500, 22)

# %%
f500.head(3)
# Out:
#                 Title                           Website  Employees  \
# 1             Walmart            http://www.walmart.com    2300000
# 2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 3               Apple              http://www.apple.com     116000
#
#        Sector                                  Industry       Hqlocation  \
# 1   Retailing                     General Merchandisers  Bentonville, AR
# 2  Financials  Insurance: Property and Casualty (Stock)        Omaha, NE
# 3  Technology               Computers, Office Equipment    Cupertino, CA
#
#                 Hqaddr       Hqcity Hqstate  Hqzip  ...  \
# 1  702 S.W. Eighth St.  Bentonville      AR  72716  ...
# 2      3555 Farnam St.        Omaha      NE  68131  ...
# 3      1 Infinite Loop    Cupertino      CA  95014  ...
#
#                                        Ceo-title  \
# 1  President, Chief Executive Officer & Director
# 2             Chairman & Chief Executive Officer
# ...

# %%
f500.head(3)
# Out:
#                 Title                           Website  Employees  \
# 1             Walmart            http://www.walmart.com    2300000
# 2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 3               Apple              http://www.apple.com     116000
#
#        Sector                                  Industry       Hqlocation  \
# 1   Retailing                     General Merchandisers  Bentonville, AR
# 2  Financials  Insurance: Property and Casualty (Stock)        Omaha, NE
# 3  Technology               Computers, Office Equipment    Cupertino, CA
#
#                 Hqaddr       Hqcity Hqstate  Hqzip  ...  \
# 1  702 S.W. Eighth St.  Bentonville      AR  72716  ...
# 2      3555 Farnam St.        Omaha      NE  68131  ...
# 3      1 Infinite Loop    Cupertino      CA  95014  ...
#
#                                        Ceo-title  \
# 1  President, Chief Executive Officer & Director
# 2             Chairman & Chief Executive Officer
# ...

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 1 to 500
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        500 non-null    object
#  1   Website      500 non-null    object
#  2   Employees    500 non-null    int64
#  3   Sector       500 non-null    object
#  4   Industry     500 non-null    object
#  5   Hqlocation   500 non-null    object
#  6   Hqaddr       500 non-null    object
#  7   Hqcity       500 non-null    object
#  8   Hqstate      500 non-null    object
#  9   Hqzip        500 non-null    int64
#  10  Hqtel        500 non-null    object
#  11  Ceo          500 non-null    object
#  12  Ceo-title    500 non-null    object
#  13  Address      500 non-null    object
#  14  Ticker       500 non-null    object
#  15  Fullname     500 non-null    object
#  16  Revenues     500 non-null    int64
#  17  Revchange    500 non-null    float64
# ...

# %%
industries = f500['Industry']

# %%
industries
# Out:
# 1                         General Merchandisers
# 2      Insurance: Property and Casualty (Stock)
# 3                   Computers, Office Equipment
# 4                            Petroleum Refining
# 5                      Wholesalers: Health Care
#                          ...
# 496                  Specialty Retailers: Other
# 497                                Homebuilders
# 498             Internet Services and Retailing
# 499                                      Energy
# 500            Diversified Outsourcing Services
# Name: Industry, Length: 500, dtype: object

# %%
title_col = f500.loc[:, 'Title']

# %%
title_col
# Out:
# 1                 Walmart
# 2      Berkshire Hathaway
# 3                   Apple
# 4             Exxon Mobil
# 5                McKesson
#               ...
# 496         Michaels Cos.
# 497         Toll Brothers
# 498                 Yahoo
# 499         Vistra Energy
# 500        ABM Industries
# Name: Title, Length: 500, dtype: object

# %%
ceo_to_fullname = f500.loc[:,'Ceo':'Fullname']

# %%
ceo_to_fullname
# Out:
#                         Ceo                                      Ceo-title  \
# 1       C. Douglas McMillon  President, Chief Executive Officer & Director
# 2         Warren E. Buffett             Chairman & Chief Executive Officer
# 3           Timothy D. Cook             Chief Executive Officer & Director
# 4           Darren W. Woods             Chairman & Chief Executive Officer
# 5        John H. Hammergren  Chairman, President & Chief Executive Officer
# ..                      ...                                            ...
# 496           Carl S. Rubin             Chairman & Chief Executive Officer
# 497  Douglas C. Yearley Jr.             Chief Executive Officer & Director
# 498        Marissa A. Mayer  President, Chief Executive Officer & Director
# 499        Curtis A. Morgan  President, Chief Executive Officer & Director
# 500        Scott B. Salmirs  President, Chief Executive Officer & Director
#
#                                         Address Ticker  \
# ...

# %%
interested_companies = f500.loc[["Coca-Cola", "Yahoo"]]

# %%
interested_companies
# Out:
#            Rank                          Website  Employees  \
# Coca-Cola    64  http://www.coca-colacompany.com     100300
# Yahoo       498             http://www.yahoo.com       8500
#
#                               Sector                         Industry  \
# Coca-Cola  Food, Beverages & Tobacco                        Beverages
# Yahoo                     Technology  Internet Services and Retailing
#
#               Hqlocation             Hqaddr     Hqcity Hqstate  Hqzip  ...  \
# Coca-Cola    Atlanta, GA  1 Coca-Cola Plaza    Atlanta      GA  30313  ...
# Yahoo      Sunnyvale, CA     701 First Ave.  Sunnyvale      CA  94089  ...
#
#                                                Ceo-title  \
# Coca-Cola  President, Chief Executive Officer & Director
# Yahoo      President, Chief Executive Officer & Director
#
#                                         Address Ticker               Fullname  \
# Coca-Cola  1 Coca-Cola Plaza, Atlanta, GA 30313     KO  The Coca-Cola Company
# ...

# %% [markdown]
# Count the most common industries

# %%
indystry_counts = industries.value_counts()

# %%
indystry_counts
# Out:
# Utilities: Gas and Electric                 22
# Specialty Retailers: Other                  21
# Insurance: Property and Casualty (Stock)    20
# Commercial Banks                            19
# Chemicals                                   14
#                                             ..
# Trucking, Truck Leasing                      2
# Waste Management                             2
# Forest and Paper Products                    1
# Transportation Equipment                     1
# Toys, Sporting Goods                         1
# Name: Industry, Length: 73, dtype: int64

# %% [markdown]
# Calculate max previous year revenue

# %%
previous_revenue =  f500["Revenues"] + f500["Revchange"]
previous_revenue_max = previous_revenue.max()

# %%
previous_revenue_max
# Out:
# 485873.8

# %%
print(previous_revenue.describe())
# Out:
# count       500.000000
# mean      24115.506000
# std       38337.119694
# min        5142.200000
# 25%        7221.625000
# 50%       11379.000000
# 75%       22612.775000
# max      485873.800000
# dtype: float64

# %%
f500.max(numeric_only=True)
# Out:
# Rank               500.0
# Employees      2300000.0
# Hqzip            98188.0
# Revenues        485873.0
# Revchange          197.3
# Profits          45687.0
# Assets         3287968.0
# Totshequity     283001.0
# dtype: float64

# %% [markdown]
# Find two mthe ost common values in the industry column for companies in Dublin.

# %%
industry_dublin = f500.loc[f500['Hqcity'] == 'Dublin',"Industry"].value_counts().head(2)

# %%
industry_dublin
# Out:
# Specialty Retailers: Apparel    1
# Wholesalers: Health Care        1
# Name: Industry, dtype: int64
